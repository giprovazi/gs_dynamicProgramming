# %%
# Lista com as profissões e suas respectivas informações
profissoes = [
    {"nome": "Engenheiro de IA", "demanda": 95, "categoria": "Tecnologia"},
    {"nome": "Analista de Sustentabilidade", "demanda": 85, "categoria": "Sustentabilidade"},
    {"nome": "Especialista em Cibersegurança", "demanda": 91, "categoria": "Segurança"},
    {"nome": "Gestor de Energia Renovável", "demanda": 88, "categoria": "Energia"},
    {"nome": "Desenvolvedor de Realidade Virtual", "demanda": 90, "categoria": "Tecnologia"},
    {"nome": "Cientista de Dados", "demanda": 93, "categoria": "Tecnologia"},
    {"nome": "Engenheiro Ambiental", "demanda": 84, "categoria": "Sustentabilidade"},
    {"nome": "Arquiteto de Nuvem", "demanda": 89, "categoria": "Tecnologia"},
    {"nome": "Técnico em Energia Solar", "demanda": 80, "categoria": "Energia"},
    {"nome": "Gestor de Resíduos", "demanda": 76, "categoria": "Sustentabilidade"},
    {"nome": "Desenvolvedor de Aplicativos", "demanda": 94, "categoria": "Tecnologia"},
    {"nome": "Especialista em Robótica", "demanda": 92, "categoria": "Tecnologia"},
    {"nome": "Pesquisador em Biotecnologia", "demanda": 83, "categoria": "Ciência"},
    {"nome": "Engenheiro de Mobilidade Elétrica", "demanda": 86, "categoria": "Energia"},
    {"nome": "Técnico em Manutenção de Drones", "demanda": 79, "categoria": "Tecnologia"},
    {"nome": "Engenheiro de Software Verde", "demanda": 87, "categoria": "Sustentabilidade"},
    {"nome": "Gestor de Projetos Sustentáveis", "demanda": 82, "categoria": "Sustentabilidade"},
    {"nome": "Analista de Dados Climáticos", "demanda": 81, "categoria": "Ciência"},
    {"nome": "Engenheiro de Materiais Renováveis", "demanda": 85, "categoria": "Sustentabilidade"},
    {"nome": "Desenvolvedor de Inteligência Artificial Ética", "demanda": 90, "categoria": "Tecnologia"},
    {"nome": "Especialista em Armazenamento de Energia", "demanda": 88, "categoria": "Energia"},
    {"nome": "Engenheiro de Automação Industrial", "demanda": 89, "categoria": "Tecnologia"},
    {"nome": "Consultor em Economia Circular", "demanda": 84, "categoria": "Sustentabilidade"},
    {"nome": "Analista de Infraestrutura de TI", "demanda": 86, "categoria": "Tecnologia"},
    {"nome": "Gestor de Inovações Energéticas", "demanda": 83, "categoria": "Energia"}
]

# Função para ordenar as profissões por demanda de forma decrescente
def ordenar_profissoes(lista):
    # sorted() retorna uma nova lista ordenada
    # key define o critério de ordenação (aqui, a demanda)
    # reverse=True deixa em ordem decrescente (maior demanda primeiro)
    return sorted(lista, key=lambda x: x["demanda"], reverse=True)

# Função para salvar as profissões em um arquivo de texto
def salvar_em_arquivo(lista_ordenada):
    # Abre (ou cria) o arquivo 'profissoes_ordenadas.txt' no modo escrita ("w")
    with open("profissoes_ordenadas.txt", "w", encoding="utf-8") as arquivo:
        # Escreve um título no arquivo
        arquivo.write("Profissões com Maior Demanda Futura\n")
        arquivo.write("=" * 45 + "\n\n")
        
        # Percorre cada profissão e escreve suas informações no arquivo
        for p in lista_ordenada:
            arquivo.write(f"Profissão: {p['nome']}\n")
            arquivo.write(f"Demanda: {p['demanda']}%\n")
            arquivo.write(f"Categoria: {p['categoria']}\n")
            arquivo.write("-" * 45 + "\n")
    
    # Exibe uma mensagem no terminal quando o arquivo é gerado com sucesso
    print("Arquivo 'profissoes_ordenadas.txt' gerado com sucesso!")

# Função principal que controla o fluxo do programa
def main():
    # Ordena a lista de profissões
    lista_ordenada = ordenar_profissoes(profissoes)
    
    # Exibe as profissões no terminal de forma organizada
    print("Profissões com maior demanda futura:\n")
    for p in lista_ordenada:
        print(f"{p['nome']} ({p['categoria']}) - Demanda: {p['demanda']}%")
    
    # Chama a função que salva os resultados em um arquivo TXT
    salvar_em_arquivo(lista_ordenada)

# Ponto de entrada do programa
# Garante que o código só execute a função main() se o arquivo for executado diretamente
if __name__ == "__main__":
    main()
# Out:
# 🔹 Ordenando profissões do futuro...
#
# 📊 RELATÓRIO - PROFISSÕES DO FUTURO
#
# Profissão                           | Demanda (%)
# --------------------------------------------------
# Engenheiro de IA                    | 95
# Cientista de Dados                  | 94
# Designer de Experiência do Usuário (UX) | 92
# Especialista em Cibersegurança      | 91
# Especialista em Segurança de Infraestruturas Críticas | 90
# Engenheiro Biomédico                | 90
# Desenvolvedor de Realidade Virtual  | 90
# Desenvolvedor de Assistentes Virtuais | 89
# Engenheiro de Robótica              | 89
# Analista de Dados Ambientais        | 88
# Consultor de Transformação Digital  | 88
# Gestor de Energia Renovável         | 88
# Engenheiro de Mobilidade Elétrica   | 87
# Especialista em Computação Quântica | 87
# Engenheiro de Materiais Sustentáveis | 86
# Desenvolvedor de Blockchain         | 86
# Especialista em Ciberpsicologia     | 85
# Analista de Sustentabilidade        | 85
# ...
